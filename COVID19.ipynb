# %%
import pandas as pd

# %% [markdown]
# # Reading data

# %%
df = pd.read_csv('datacov.csv')

# %%
df.head()
# Out:
#    fever  bodyPain  age  runynose  difBreath  infectionProb
# 0     99         0   40         0          1              1
# 1    100         1   91         1          1              0
# 2     99         0   18         0          0              1
# 3    101         1   92         1          0              0
# 4     99         0    6         0          1              1

# %%
df.tail()
# Out:
#       fever  bodyPain  age  runynose  difBreath  infectionProb
# 2499    100         0   44         1          0              1
# 2500    102         1   39         0          0              1
# 2501     99         0   60         0          0              0
# 2502     99         0   20         1          1              1
# 2503    103         1   71         0          0              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2504 entries, 0 to 2503
# Data columns (total 6 columns):
# fever            2504 non-null int64
# bodyPain         2504 non-null int64
# age              2504 non-null int64
# runynose         2504 non-null int64
# difBreath        2504 non-null int64
# infectionProb    2504 non-null int64
# dtypes: int64(6)
# memory usage: 117.5 KB

# %%
df['difBreath'].value_counts()
# Out:
# -1    849
#  0    833
#  1    822
# Name: difBreath, dtype: int64

# %%
df.describe()
# Out:
#              fever     bodyPain          age     runynose    difBreath  \
# count  2504.000000  2504.000000  2504.000000  2504.000000  2504.000000
# mean    101.547923     0.487220    50.276358     0.484026    -0.010783
# std       1.688750     0.499936    28.951409     0.499845     0.816996
# min      99.000000     0.000000     1.000000     0.000000    -1.000000
# 25%     100.000000     0.000000    25.000000     0.000000    -1.000000
# 50%     102.000000     0.000000    50.000000     0.000000     0.000000
# 75%     103.000000     1.000000    75.000000     1.000000     1.000000
# max     104.000000     1.000000   100.000000     1.000000     1.000000
#
#        infectionProb
# count    2504.000000
# mean        0.501198
# std         0.500098
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# # Train Test Splitting

# %%
import numpy as np

# %%
def data_split(data, ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * ratio)
    test_indices = shuffled[:test_set_size] #all rows & testsetsizecolumn
    train_indices = shuffled[test_set_size:] #first
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train, test = data_split(df, 0.2)

# %%
train
# Out:
#       fever  bodyPain  age  runynose  difBreath  infectionProb
# 1435    103         1   69         0          0              1
# 2020     99         0   76         1          0              0
# 342     104         0   34         1          1              0
# 1978     99         1   56         1          1              0
# 2079    102         0   42         0         -1              1
# 2026    101         0    6         0          1              1
# 1463    100         0   70         1          0              1
# 299     102         0   95         1          1              1
# 1128    102         0   93         0          1              0
# 2498    104         1   44         0          0              0
# 2383    103         1   10         1          1              1
# 1565     99         0   49         0         -1              1
# 2275     99         1   29         1          1              1
# 1501    104         0   85         0          1              0
# ...

# %%
test
# Out:
#       fever  bodyPain  age  runynose  difBreath  infectionProb
# 1835    101         1   44         1         -1              1
# 252     104         1   55         1          1              1
# 1594    100         0   95         0         -1              1
# 430     103         1   31         0          0              0
# 1356     99         0   71         1          1              0
# 1620     99         0   22         0         -1              0
# 2196     99         0   26         0          1              0
# 1070    104         1   22         1          0              0
# 239     102         1   52         0         -1              0
# 1486    100         0   30         0         -1              0
# 2221    102         0   58         0          1              1
# 354     102         0   71         1         -1              1
# 445     101         0   74         1          0              1
# 2031    102         1   22         0          0              1
# ...

# %%
X_train = train[['fever', 'bodyPain', 'age', 'runynose', 'difBreath']].to_numpy()
X_test = test[['fever', 'bodyPain', 'age', 'runynose', 'difBreath']].to_numpy()

# %%
X_train
# Out:
# array([[103,   1,  69,   0,   0],
#        [ 99,   0,  76,   1,   0],
#        [104,   0,  34,   1,   1],
#        ...,
#        [103,   0,  48,   1,   0],
#        [ 99,   1,   9,   1,   1],
#        [101,   0,  11,   1,   0]], dtype=int64)

# %%
Y_train = train[['infectionProb']].to_numpy().reshape(2004,)
Y_test = test[['infectionProb']].to_numpy().reshape(500,)

# %%
Y_train
# Out:
# array([1, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# C:\Users\Dell\Anaconda4\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
inputFeatures = [100,1,22,-1,1]
infProb = clf.predict_proba([inputFeatures])[0][1]

# %%
infProb
# Out:
# 0.5295655850428443

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\covid predn'

# %%
2+1
# Out:
# 3
